# %%
from preprocess import preprocess
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
prep = preprocess()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 prep = preprocess()
#
# File ~/Documents/anomaly-detection/anomaly-detection-in-HEP/src/dataset/preprocess.py:34, in preprocess.__init__(self, bucket_name, features, signal_files, background_file, data_size)
#      32 self.features = features
#      33 self.bucket_name = bucket_name
# ---> 34 self._read_data(signal_files, background_file)
#
# File ~/Documents/anomaly-detection/anomaly-detection-in-HEP/src/dataset/preprocess.py:148, in preprocess._read_data(self, signal_files, background_file)
#     140 def _read_data(self, signal_files:list[str], background_file:str):
#     141     """
#     142     Reads the signal and background data.
#     143
#    (...)
#     146         background_file (str): File path of the background data.
#     147     """
# --> 148     self.signal_data = self._read_signal_data(signal_files)
#     149     self.background_data = self._read_background_data(background_file, self.features)
#
# File ~/Documents/anomaly-detection/anomaly-detection-in-HEP/src/dataset/preprocess.py:130, in preprocess._read_signal_data(self, file_dirs)
#     128     data = self.select_data_in_root_data(data)
#     129 elif file_dir.endswith('.h5'):
# --> 130     data = self._get_data_from_h5(file_dir)
#     131 else:
#     132     raise ValueError("Invalid file format. Only .root and .h5 files are supported.")
#
# File ~/Documents/anomaly-detection/anomaly-detection-in-HEP/src/dataset/preprocess.py:67, in preprocess._get_data_from_h5(self, file_dir)
#      65 bucket = client.get_bucket(self.bucket_name)
#      66 blob = bucket.blob(file_dir)
# ---> 67 file_contents = BytesIO(blob.download_as_string())
#      68 with h5py.File(file_contents, 'r') as f:
#      69     dataset = f['Track']
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/cloud/storage/blob.py:1550, in Blob.download_as_string(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, retry)
#    1468 """(Deprecated) Download the contents of this blob as a bytes object.
#    1469
#    1470 If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1545 :raises: :class:`google.cloud.exceptions.NotFound`
#    1546 """
#    1547 warnings.warn(
#    1548     _DOWNLOAD_AS_STRING_DEPRECATED, PendingDeprecationWarning, stacklevel=2
#    1549 )
# -> 1550 return self.download_as_bytes(
#    1551     client=client,
#    1552     start=start,
#    1553     end=end,
#    1554     raw_download=raw_download,
#    1555     if_etag_match=if_etag_match,
#    1556     if_etag_not_match=if_etag_not_match,
#    1557     if_generation_match=if_generation_match,
#    1558     if_generation_not_match=if_generation_not_match,
#    1559     if_metageneration_match=if_metageneration_match,
#    1560     if_metageneration_not_match=if_metageneration_not_match,
#    1561     timeout=timeout,
#    1562     retry=retry,
#    1563 )
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/cloud/storage/blob.py:1435, in Blob.download_as_bytes(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1345 """Download the contents of this blob as a bytes object.
#    1346
#    1347 If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1430 :raises: :class:`google.cloud.exceptions.NotFound`
#    1431 """
#    1433 string_buffer = BytesIO()
# -> 1435 self._prep_and_do_download(
#    1436     string_buffer,
#    1437     client=client,
#    1438     start=start,
#    1439     end=end,
#    1440     raw_download=raw_download,
#    1441     if_etag_match=if_etag_match,
#    1442     if_etag_not_match=if_etag_not_match,
#    1443     if_generation_match=if_generation_match,
#    1444     if_generation_not_match=if_generation_not_match,
#    1445     if_metageneration_match=if_metageneration_match,
#    1446     if_metageneration_not_match=if_metageneration_not_match,
#    1447     timeout=timeout,
#    1448     checksum=checksum,
#    1449     retry=retry,
#    1450 )
#    1451 return string_buffer.getvalue()
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/cloud/storage/blob.py:4362, in Blob._prep_and_do_download(self, file_obj, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    4359 transport = client._http
#    4361 try:
# -> 4362     self._do_download(
#    4363         transport,
#    4364         file_obj,
#    4365         download_url,
#    4366         headers,
#    4367         start,
#    4368         end,
#    4369         raw_download,
#    4370         timeout=timeout,
#    4371         checksum=checksum,
#    4372         retry=retry,
#    4373     )
#    4374 except resumable_media.InvalidResponse as exc:
#    4375     _raise_from_invalid_response(exc)
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/cloud/storage/blob.py:1017, in Blob._do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#    1008     download = klass(
#    1009         download_url,
#    1010         stream=file_obj,
#    (...)
#    1014         checksum=checksum,
#    1015     )
#    1016     download._retry_strategy = retry_strategy
# -> 1017     response = download.consume(transport, timeout=timeout)
#    1018     self._extract_headers_from_download(response)
#    1019 else:
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/resumable_media/requests/download.py:237, in Download.consume(self, transport, timeout)
#     233         self._write_to_stream(result)
#     235     return result
# --> 237 return _request_helpers.wait_and_retry(
#     238     retriable_request, self._get_status_code, self._retry_strategy
#     239 )
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/resumable_media/requests/download.py:233, in Download.consume.<locals>.retriable_request()
#     230             raise Exception(msg) from exc
#     231         self._bytes_downloaded = 0
# --> 233     self._write_to_stream(result)
#     235 return result
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/google/resumable_media/requests/download.py:123, in Download._write_to_stream(self, response)
#     119 local_checksum_object = _add_decoder(response.raw, checksum_object)
#     120 body_iter = response.iter_content(
#     121     chunk_size=_request_helpers._SINGLE_GET_CHUNK_SIZE, decode_unicode=False
#     122 )
# --> 123 for chunk in body_iter:
#     124     self._stream.write(chunk)
#     125     self._bytes_downloaded += len(chunk)
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/urllib3/response.py:1043, in HTTPResponse.stream(self, amt, decode_content)
#    1041 else:
#    1042     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1043         data = self.read(amt=amt, decode_content=decode_content)
#    1045         if data:
#    1046             yield data
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/urllib3/response.py:935, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     932     if len(self._decoded_buffer) >= amt:
#     933         return self._decoded_buffer.get(amt)
# --> 935 data = self._raw_read(amt)
#     937 flush_decoder = amt is None or (amt != 0 and not data)
#     939 if not data and len(self._decoded_buffer) == 0:
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/urllib3/response.py:862, in HTTPResponse._raw_read(self, amt, read1)
#     859 fp_closed = getattr(self._fp, "closed", False)
#     861 with self._error_catcher():
# --> 862     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     863     if amt is not None and amt != 0 and not data:
#     864         # Platform-specific: Buggy versions of Python.
#     865         # Close the connection when no data is returned
#    (...)
#     870         # not properly close the connection in all cases. There is
#     871         # no harm in redundantly calling close.
#     872         self._fp.close()
#
# File ~/Documents/anomaly-detection/venv/lib/python3.12/site-packages/urllib3/response.py:845, in HTTPResponse._fp_read(self, amt, read1)
#     842     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     843 else:
#     844     # StringIO doesn't like amt=None
# --> 845     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /usr/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /usr/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
prep.print_desc_stats()

# %%
prep.save_data('../../data/data_preprocessed.h5')
